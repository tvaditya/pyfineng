# %%
import pandas as pd

# %%
df = pd.read_csv('sp500sub.csv', index_col='Date', parse_dates=True)

# %%
df.shape
# Out:
# (326804, 7)

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  Name
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.505280  493729600  AAPL
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.516527  601904800  AAPL
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.412872  552160000  AAPL
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.401016  477131200  AAPL
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.443573  447610800  AAPL

# %%
goog = df[df['Name'] == 'GOOG']
goog[['Close', 'Adj Close']].plot(figsize=(10, 10))
# Out:
# <Axes: xlabel='Date'>

# %%
aapl = df[df['Name'] == 'AAPL']
aapl[['Close', 'Adj Close']].plot(figsize=(10, 10))
# Out:
# <Axes: xlabel='Date'>

# %%
aapl.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-02-13  150.949997  154.259995  150.919998  153.850006  153.850006
# 2023-02-14  152.119995  153.770004  150.860001  153.199997  153.199997
# 2023-02-15  153.110001  155.500000  152.880005  155.330002  155.330002
# 2023-02-16  153.509995  156.330002  153.350006  153.710007  153.710007
# 2023-02-17  152.350006  153.000000  150.850006  152.550003  152.550003
#
#               Volume  Name
# Date
# 2023-02-13  62199000  AAPL
# 2023-02-14  61707600  AAPL
# 2023-02-15  65669300  AAPL
# 2023-02-16  68167900  AAPL
# 2023-02-17  59095900  AAPL
